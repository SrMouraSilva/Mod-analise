# %% [markdown]
# # 2.2 - Tratamento dos dados - Dicionário para rotulação
#
# Será criado um dicionário de palavras com base nos pedalboards obtidos no passo anterior.
# Como há uma baixa quantidade de patches, é complicado obter todas as palavras boas, uma alternativa é pegar de um outro banco:
#
# * http://guitarpatches.com/units.php

# %%
import nltk

tokenize = lambda phase: [word.lower() for word in nltk.word_tokenize(phase)]

# %% [markdown]
# ## tokens

# %%
import pandas as pd
tokens = []

pedalboards = pd.read_json('mod-pedalboards-v2.json', orient='columns')

for title, description in zip (pedalboards['title'], pedalboards['description']):
    tokens += tokenize(title) + tokenize(description)

tokens
# Out:
# ['basic',
#  'power',
#  'trio',
#  'guit',
#  'practical',
#  'set',
#  'for',
#  'basic',
#  'power',
#  'trio',
#  'gigs',
#  '.',
#  'clean',
#  ',',
#  'drive',
#  ',',
#  'and',
#  'solo',
#  'delay',
#  '...',
#  'crunch',
#  'with',
#  'clean',
#  'ambience',
#  'a',
#  'strong',
#  'crunch',
#  '(',
#  'ds',
#  ')',
#  ',',
#  'with',
#  'deep',
#  'and',
#  'clean',
#  'ambience',
#  '.',
#  'using',
#  'ds-1',
#  'in',
#  'parallel',
#  'with',
#  'chorus',
#  ',',
#  'delay',
#  '(',
#  'shiro',
#  ')',
#  'and',
#  'shimmer',
#  'in',
#  'clean',
#  'channel',
#  '.',
#  'dual',
#  'channel',
#  'bleepy',
#  'ambience',
#  'and',
#  'overdriven',
#  'lead',
#  'this',
#  'is',
#  'an',
#  'updated',
#  'version',
#  'of',
#  'the',
#  'board',
#  'i',
#  'used',
#  'on',
#  'the',
#  'track',
#  "'this",
#  'is',
#  'not',
#  'the',
#  'end',
#  "'",
#  ',',
#  'that',
#  "'s",
#  'on',
#  'youtube',
#  '(',
#  'search',
#  'for',
#  'steve',
#  'lawson',
#  '+',
#  'the',
#  'title',
#  ')',
#  '-',
#  'f/s',
#  '2',
#  'switches',
#  'between',
#  'the',
#  'two',
#  'sides',
#  'of',
#  'the',
#  'chain',
#  ',',
#  'and',
#  'i',
#  "'ve",
#  'got',
#  'the',
#  'overdrive',
#  ',',
#  'phaser',
#  'and',
#  'delay',
#  'assigned',
#  'to',
#  'midi',
#  'controls',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'controls',
#  'for',
#  'the',
#  'looper',
#  '...',
#  'br',
#  '-',
#  'ringm-scream-loop',
#  'lots',
#  'of',
#  'sounds',
#  ',',
#  'lots',
#  'of',
#  'fun..',
#  'shimmer2',
#  'version',
#  '2',
#  'of',
#  'my',
#  'shimmer/swell',
#  'pedalboard',
#  '.',
#  'easily',
#  'pull',
#  'of',
#  'ambient',
#  'swells',
#  'using',
#  'your',
#  'volume',
#  'pedal',
#  ',',
#  'or',
#  'pluck',
#  'single',
#  'notes',
#  'intermittently',
#  'for',
#  'stronger',
#  'clearer',
#  'attacks',
#  'for',
#  'simple',
#  'solos',
#  '.',
#  'evening',
#  'pulse',
#  'two',
#  'mic',
#  'one',
#  'vocal',
#  'game',
#  'early',
#  'jamming',
#  'some',
#  'quick',
#  'jamming',
#  'for',
#  'pre-lunch',
#  'fun',
#  '!',
#  '!',
#  '!',
#  'plugged',
#  'the',
#  'gret',
#  'jcm-800',
#  'to',
#  'a',
#  'cabinet',
#  'and',
#  'added',
#  'the',
#  'phaser',
#  'for',
#  'a',
#  'funky',
#  'vibe',
#  '.',
#  'the',
#  'very',
#  'basic',
#  'drum',
#  'is',
#  'provided',
#  'by',
#  'x42',
#  "'s",
#  'midi',
#  'sequencer',
#  'coupled',
#  'to',
#  'the',
#  'fluiddrums',
#  '.',
#  'looped',
#  'everything',
#  'to',
#  'jam',
#  'with',
#  'myself',
#  'a',
#  'bit',
#  ':',
#  '-',
#  ')',
#  'midi',
#  'loopback',
#  'by',
#  'connecting',
#  'the',
#  'din-midi',
#  'output',
#  'to',
#  'the',
#  'din-midi',
#  'input',
#  ',',
#  'we',
#  'can',
#  'change',
#  'the',
#  'midi',
#  'messages',
#  'we',
#  'are',
#  'receiving',
#  ',',
#  'and',
#  'use',
#  'them',
#  'for',
#  'different',
#  'plugins',
#  '.',
#  'in',
#  'this',
#  'board',
#  ',',
#  'we',
#  'duplicate',
#  'cc14',
#  'to',
#  'cc44',
#  'to',
#  'control',
#  'two',
#  'parameters',
#  'at',
#  'once',
#  '(',
#  'width',
#  'of',
#  'the',
#  'pingpong',
#  'panner',
#  'and',
#  'the',
#  'depth',
#  'of',
#  'shiro',
#  'harmless',
#  ')',
#  '.',
#  'we',
#  'also',
#  'transpose',
#  'the',
#  'note',
#  'an',
#  'octave',
#  'down',
#  'and',
#  'an',
#  'octave',
#  'up',
#  '.',
#  'try',
#  'it',
#  'out',
#  'and',
#  'get',
#  'creative',
#  '!',
#  'shine',
#  'playing',
#  'a',
#  'bass',
#  'patch',
#  'with',
#  'optional',
#  '+3/-3',
#  ',',
#  'close',
#  'to',
#  '``',
#  'shine',
#  "''",
#  'by',
#  '``',
#  'the',
#  'cool',
#  'quest',
#  "''",
#  '.',
#  'mods',
#  'cpu',
#  'at',
#  'it',
#  "'s",
#  'max',
#  ':',
#  ')',
#  'money',
#  'for',
#  'something',
#  'first',
#  'try',
#  'with',
#  'modduo',
#  '.',
#  'i',
#  'tried',
#  'to',
#  'get',
#  'a',
#  'kind',
#  'of',
#  '``',
#  'money',
#  'for',
#  'nothing',
#  "''",
#  'tone',
#  '.',
#  'intended',
#  'for',
#  'headphones',
#  'output',
#  ':',
#  'i',
#  'hav',
#  "n't",
#  'tried',
#  'on',
#  'a',
#  'real',
#  'amp',
#  '.',
#  'gxjcm800test',
#  'just',
#  'a',
#  'short',
#  'test',
#  'od-leslie',
#  'organ',
#  'player',
#  'ca',
#  "n't",
#  'make',
#  'the',
#  'gig',
#  '?',
#  'no',
#  'midi',
#  'keyboard',
#  '?',
#  'no',
#  'problem',
#  '!',
#  'mod',
#  'duo',
#  'to',
#  'the',
#  'rescue',
#  'with',
#  'the',
#  'setbfree',
#  "'whirl",
#  "'",
#  'speaker',
#  'leslie',
#  'emulation',
#  '.',
#  'to',
#  'fake',
#  'organ',
#  'sounds',
#  'roll',
#  'back',
#  'the',
#  'tone',
#  'on',
#  'your',
#  'rhythm',
#  'pickup',
#  'and',
#  'play',
#  'fingerstyle',
#  'with',
#  'lots',
#  'of',
#  'high',
#  'drone',
#  'notes',
#  '.',
#  'do',
#  "n't",
#  'forget',
#  'if',
#  'you',
#  'do',
#  'have',
#  'a',
#  'midi',
#  'keyboard',
#  'you',
#  'can',
#  'emulate',
#  'the',
#  'real',
#  'hammond',
#  'b3',
#  'thing',
#  'with',
#  'the',
#  'setbfree',
#  'organ',
#  'generator',
#  ',',
#  'this',
#  'pedalboard',
#  'is',
#  'for',
#  'faking',
#  'it',
#  'with',
#  'a',
#  'guitar',
#  '.',
#  'harmless',
#  'jcm',
#  'trying',
#  'out',
#  'the',
#  'jcm-800',
#  'and',
#  'the',
#  'shiro',
#  'harmless',
#  'modulator',
#  '.',
#  'such',
#  'a',
#  'beautiful',
#  'sound',
#  '!',
#  '!',
#  '!',
#  'uoyhtiw',
#  'experiments',
#  'with',
#  'sequencers',
#  ',',
#  'and',
#  'voice',
#  '.',
#  'in',
#  'the',
#  'arms',
#  'of',
#  'ac30',
#  ',',
#  'delay',
#  ',',
#  'reverbs',
#  '!',
#  'the',
#  'knifes',
#  'reverbery',
#  'ac30',
#  'and',
#  'jcm',
#  '.',
#  '+',
#  'having',
#  'fun',
#  'with',
#  'whammied',
#  'voice',
#  '(',
#  'like',
#  'in',
#  'the',
#  'knife',
#  ';',
#  ')',
#  ')',
#  'midistuffdemo',
#  'just',
#  'an',
#  'experiment',
#  'synthesizers',
#  'can',
#  'make',
#  'music',
#  'first',
#  'attempt',
#  'with',
#  'synthesizers',
#  'and',
#  'keyboard',
#  'on',
#  'mod',
#  'duo',
#  '.',
#  'i',
#  'think',
#  'i',
#  'found',
#  'a',
#  'new',
#  'favorite',
#  'thing',
#  '.',
#  'shimmermachine',
#  'using',
#  'the',
#  'new',
#  'harmless',
#  'by',
#  'shiro',
#  ',',
#  'combined',
#  'with',
#  'the',
#  'larynx',
#  'on',
#  'my',
#  'novation',
#  'circuit',
#  '.',
#  'also',
#  'using',
#  'the',
#  'new',
#  'guitarix',
#  'vibrochump',
#  ',',
#  'spiced',
#  'up',
#  'by',
#  'the',
#  'tap',
#  'tubewarmth',
#  'for',
#  'a',
#  'warmer',
#  'sound',
#  '.',
#  'the',
#  'shiroverbs',
#  'are',
#  'set',
#  'to',
#  'octave',
#  'down',
#  'and',
#  'octave',
#  'up',
#  'for',
#  'very',
#  'different',
#  'shimmer',
#  'sounds',
#  '.',
#  'loop',
#  '+',
#  'harmonicos',
#  'acostumando',
#  'com',
#  'o',
#  'loop',
#  ',',
#  'da',
#  'pra',
#  'fazer',
#  'muita',
#  'coisa',
#  'com',
#  'isso',
#  '...',
#  '.lindo',
#  '!',
#  'musica',
#  'segredos',
#  '-',
#  'trem',
#  'de',
#  'carga',
#  'circuitjam',
#  'i',
#  "'m",
#  'using',
#  'the',
#  'novation',
#  'circuit',
#  'as',
#  'a',
#  'midi-controller',
#  'for',
#  'the',
#  'mod',
#  'duo',
#  '.',
#  'the',
#  'duo',
#  'has',
#  'great',
#  'midi-filtering',
#  'capabilities',
#  ',',
#  'so',
#  'i',
#  'filtered',
#  'the',
#  'individual',
#  'sequenced',
#  'tracks',
#  'and',
#  'hooked',
#  'them',
#  'up',
#  'to',
#  'a',
#  'drummachine',
#  ',',
#  'bass-synth',
#  'and',
#  'e-piano',
#  '.',
#  'epic',
#  'strummed',
#  'synth',
#  'great',
#  'for',
#  'testing',
#  'speakers',
#  'because',
#  'it',
#  'generates',
#  'an',
#  'extremely',
#  'wide',
#  'range',
#  'of',
#  'frequencies',
#  '.',
#  'sit',
#  'on',
#  'your',
#  'subwoofer',
#  '.',
#  'cottonmouth',
#  'lives',
#  'the',
#  'pedal',
#  'combination',
#  'of',
#  'chorus/flanger',
#  'and',
#  'cabinet',
#  'give',
#  'a',
#  'warm',
#  ',',
#  'thick',
#  'distortion',
#  'while',
#  'still',
#  'leaving',
#  'space',
#  'for',
#  'lingering',
#  'frequencies',
#  'to',
#  'fit',
#  'amongst',
#  'the',
#  'deep',
#  'low',
#  'end',
#  '.',
#  'i',
#  'mostly',
#  'recently',
#  'used',
#  'this',
#  'pedalboard',
#  'for',
#  'a',
#  'new',
#  'song',
#  'with',
#  'rj',
#  'thyme',
#  '.',
#  'check',
#  'it',
#  'out',
#  'below',
#  ':',
#  'https',
#  ':',
#  '//soundcloud.com/rjthyme/god-is-music-feat-klaas-von-karlos',
#  'od-octave',
#  'i',
#  'was',
#  'looking',
#  'to',
#  'emulate',
#  'my',
#  'boss',
#  'oc-3',
#  'pedal',
#  'which',
#  'features',
#  'both',
#  'octave',
#  'and',
#  'fuzz',
#  ',',
#  'i',
#  'tried',
#  'the',
#  'mod',
#  'guitarix',
#  'oc-2',
#  'emulation',
#  'and',
#  'the',
#  'mod',
#  'mda-subsynth',
#  'but',
#  'both',
#  'were',
#  'pretty',
#  'messy',
#  'and',
#  'lost',
#  'tracking',
#  'pretty',
#  'quickly',
#  'especially',
#  'when',
#  'playing',
#  'fast',
#  '.',
#  'i',
#  'was',
#  'able',
#  'to',
#  'utilize',
#  'the',
#  '2voices',
#  'plugin',
#  'with',
#  'the',
#  'tubescreamer',
#  'and',
#  'get',
#  'a',
#  'righteous',
#  'octave',
#  'fuzz',
#  'that',
#  'tracks',
#  'nicely',
#  '.',
#  '2voices',
#  'is',
#  'set',
#  'to',
#  'have',
#  "'step1",
#  "'",
#  'dropped',
#  'an',
#  'octave',
#  'and',
#  'step2',
#  'retains',
#  'the',
#  'original',
#  'actual',
#  'pitch',
#  '.',
#  'unfortunately',
#  'there',
#  'was',
#  'not',
#  'enough',
#  'spare',
#  'cpu',
#  'to',
#  'record',
#  'a',
#  'sample',
#  '.',
#  'endless',
#  'feed',
#  'this',
#  'patch',
#  'seconds',
#  'of',
#  'signal',
#  'and',
#  'enjoy',
#  'it',
#  'for',
#  'hours',
#  '.',
#  'set',
#  'up',
#  'as',
#  'a',
#  'send',
#  'effect',
#  '.',
#  'deep',
#  'well',
#  'a',
#  'kind',
#  'of',
#  'maximalistic',
#  'reverb',
#  '.',
#  'set',
#  'up',
#  'as',
#  'a',
#  'send',
#  'effect',
#  '.',
#  'above',
#  'our',
#  'heads',
#  'voices',
#  'from',
#  'somewhere',
#  'above',
#  'our',
#  'heads',
#  'pick',
#  'up',
#  'your',
#  'signal',
#  'and',
#  'sing',
#  'with',
#  'you',
#  '.',
#  ';',
#  ')',
#  'set',
#  'up',
#  'as',
#  'a',
#  'send',
#  'effect',
#  '.',
#  'chorus',
#  'maniac',
#  '(',
#  'clean',
#  'funk',
#  'gtr',
#  ')',
#  'clean',
#  'sounds',
#  'for',
#  'rhythm',
#  'guitar',
#  '.',
#  'in',
#  'this',
#  'one',
#  'i',
#  'added',
#  'a',
#  'little',
#  'bit',
#  'of',
#  'compression',
#  'to',
#  'the',
#  'dry',
#  'signal',
#  'and',
#  'a',
#  'gain',
#  'control',
#  'to',
#  'the',
#  'chorus',
#  'signal',
#  '.',
#  'http',
#  ':',
#  '//www.rogeriocouto.com.br',
#  'chorus',
#  'maniac',
#  'klean',
#  'aula',
#  '#',
#  '1',
#  'a',
#  'clean',
#  'patch',
#  'with',
#  'some',
#  'nice',
#  'reverb',
#  '.',
#  'pink',
#  'floyd',
#  '-',
#  'shine',
#  'on',
#  'you',
#  'crazy',
#  'diamond',
#  'i',
#  'tried',
#  'as',
#  'much',
#  'as',
#  'possible',
#  'to',
#  'make',
#  'the',
#  'same',
#  'sound',
#  'mixer',
#  ',',
#  'reverb',
#  'and',
#  'click',
#  '[',
#  'rogeriocouto.com.br',
#  ']',
#  'just',
#  'a',
#  'some',
#  'tools',
#  'to',
#  'use',
#  'with',
#  'my',
#  'students',
#  'c',
#  'major',
#  'accompaniment',
#  'fun',
#  'with',
#  'step-sequencer',
#  '&',
#  'midi',
#  'utils',
#  '--',
#  'jam',
#  'along',
#  'mod',
#  'on',
#  ...]

# %% [markdown]
# ## Tagging

# %%
lancaster = nltk.LancasterStemmer()

taggs = nltk.pos_tag(tokens, tagset="universal")

taggs
# Out:
# [('basic', 'ADJ'),
#  ('power', 'NOUN'),
#  ('trio', 'NOUN'),
#  ('guit', 'NOUN'),
#  ('practical', 'ADJ'),
#  ('set', 'NOUN'),
#  ('for', 'ADP'),
#  ('basic', 'ADJ'),
#  ('power', 'NOUN'),
#  ('trio', 'NOUN'),
#  ('gigs', 'NOUN'),
#  ('.', '.'),
#  ('clean', 'ADJ'),
#  (',', '.'),
#  ('drive', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('solo', 'ADJ'),
#  ('delay', 'NOUN'),
#  ('...', '.'),
#  ('crunch', 'NOUN'),
#  ('with', 'ADP'),
#  ('clean', 'ADJ'),
#  ('ambience', 'NOUN'),
#  ('a', 'DET'),
#  ('strong', 'ADJ'),
#  ('crunch', 'NOUN'),
#  ('(', '.'),
#  ('ds', 'NOUN'),
#  (')', '.'),
#  (',', '.'),
#  ('with', 'ADP'),
#  ('deep', 'ADJ'),
#  ('and', 'CONJ'),
#  ('clean', 'ADJ'),
#  ('ambience', 'NOUN'),
#  ('.', '.'),
#  ('using', 'VERB'),
#  ('ds-1', 'ADJ'),
#  ('in', 'ADP'),
#  ('parallel', 'ADJ'),
#  ('with', 'ADP'),
#  ('chorus', 'NOUN'),
#  (',', '.'),
#  ('delay', 'NOUN'),
#  ('(', '.'),
#  ('shiro', 'NOUN'),
#  (')', '.'),
#  ('and', 'CONJ'),
#  ('shimmer', 'NOUN'),
#  ('in', 'ADP'),
#  ('clean', 'ADJ'),
#  ('channel', 'NOUN'),
#  ('.', '.'),
#  ('dual', 'ADJ'),
#  ('channel', 'NOUN'),
#  ('bleepy', 'NOUN'),
#  ('ambience', 'NOUN'),
#  ('and', 'CONJ'),
#  ('overdriven', 'ADV'),
#  ('lead', 'VERB'),
#  ('this', 'DET'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('updated', 'ADJ'),
#  ('version', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('board', 'NOUN'),
#  ('i', 'NOUN'),
#  ('used', 'VERB'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('track', 'NOUN'),
#  ("'this", 'NOUN'),
#  ('is', 'VERB'),
#  ('not', 'ADV'),
#  ('the', 'DET'),
#  ('end', 'NOUN'),
#  ("'", 'PRT'),
#  (',', '.'),
#  ('that', 'DET'),
#  ("'s", 'VERB'),
#  ('on', 'ADP'),
#  ('youtube', 'NOUN'),
#  ('(', '.'),
#  ('search', 'NOUN'),
#  ('for', 'ADP'),
#  ('steve', 'ADJ'),
#  ('lawson', 'NOUN'),
#  ('+', 'VERB'),
#  ('the', 'DET'),
#  ('title', 'NOUN'),
#  (')', '.'),
#  ('-', '.'),
#  ('f/s', '.'),
#  ('2', 'NUM'),
#  ('switches', 'NOUN'),
#  ('between', 'ADP'),
#  ('the', 'DET'),
#  ('two', 'NUM'),
#  ('sides', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('chain', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('i', 'ADJ'),
#  ("'ve", 'VERB'),
#  ('got', 'VERB'),
#  ('the', 'DET'),
#  ('overdrive', 'ADJ'),
#  (',', '.'),
#  ('phaser', 'NOUN'),
#  ('and', 'CONJ'),
#  ('delay', 'NOUN'),
#  ('assigned', 'VERB'),
#  ('to', 'PRT'),
#  ('midi', 'VERB'),
#  ('controls', 'NOUN'),
#  (',', '.'),
#  ('as', 'ADV'),
#  ('well', 'ADV'),
#  ('as', 'ADP'),
#  ('the', 'DET'),
#  ('controls', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('looper', 'NOUN'),
#  ('...', '.'),
#  ('br', 'X'),
#  ('-', '.'),
#  ('ringm-scream-loop', 'ADJ'),
#  ('lots', 'NOUN'),
#  ('of', 'ADP'),
#  ('sounds', 'NOUN'),
#  (',', '.'),
#  ('lots', 'NOUN'),
#  ('of', 'ADP'),
#  ('fun..', 'ADJ'),
#  ('shimmer2', 'ADJ'),
#  ('version', 'NOUN'),
#  ('2', 'NUM'),
#  ('of', 'ADP'),
#  ('my', 'PRON'),
#  ('shimmer/swell', 'NOUN'),
#  ('pedalboard', 'ADV'),
#  ('.', '.'),
#  ('easily', 'ADV'),
#  ('pull', 'NOUN'),
#  ('of', 'ADP'),
#  ('ambient', 'NOUN'),
#  ('swells', 'NOUN'),
#  ('using', 'VERB'),
#  ('your', 'PRON'),
#  ('volume', 'NOUN'),
#  ('pedal', 'NOUN'),
#  (',', '.'),
#  ('or', 'CONJ'),
#  ('pluck', 'ADJ'),
#  ('single', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('intermittently', 'ADV'),
#  ('for', 'ADP'),
#  ('stronger', 'ADJ'),
#  ('clearer', 'NOUN'),
#  ('attacks', 'NOUN'),
#  ('for', 'ADP'),
#  ('simple', 'ADJ'),
#  ('solos', 'NOUN'),
#  ('.', '.'),
#  ('evening', 'VERB'),
#  ('pulse', 'ADJ'),
#  ('two', 'NUM'),
#  ('mic', 'ADJ'),
#  ('one', 'NUM'),
#  ('vocal', 'ADJ'),
#  ('game', 'NOUN'),
#  ('early', 'ADJ'),
#  ('jamming', 'NOUN'),
#  ('some', 'DET'),
#  ('quick', 'ADJ'),
#  ('jamming', 'NOUN'),
#  ('for', 'ADP'),
#  ('pre-lunch', 'ADJ'),
#  ('fun', 'NOUN'),
#  ('!', '.'),
#  ('!', '.'),
#  ('!', '.'),
#  ('plugged', 'VERB'),
#  ('the', 'DET'),
#  ('gret', 'ADJ'),
#  ('jcm-800', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('cabinet', 'NOUN'),
#  ('and', 'CONJ'),
#  ('added', 'VERB'),
#  ('the', 'DET'),
#  ('phaser', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('funky', 'ADJ'),
#  ('vibe', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('very', 'ADV'),
#  ('basic', 'ADJ'),
#  ('drum', 'NOUN'),
#  ('is', 'VERB'),
#  ('provided', 'VERB'),
#  ('by', 'ADP'),
#  ('x42', 'NOUN'),
#  ("'s", 'PRT'),
#  ('midi', 'NOUN'),
#  ('sequencer', 'NOUN'),
#  ('coupled', 'VERB'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('fluiddrums', 'NOUN'),
#  ('.', '.'),
#  ('looped', 'VERB'),
#  ('everything', 'NOUN'),
#  ('to', 'PRT'),
#  ('jam', 'VERB'),
#  ('with', 'ADP'),
#  ('myself', 'PRON'),
#  ('a', 'DET'),
#  ('bit', 'NOUN'),
#  (':', '.'),
#  ('-', '.'),
#  (')', '.'),
#  ('midi', 'X'),
#  ('loopback', 'NOUN'),
#  ('by', 'ADP'),
#  ('connecting', 'VERB'),
#  ('the', 'DET'),
#  ('din-midi', 'ADJ'),
#  ('output', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('din-midi', 'ADJ'),
#  ('input', 'NOUN'),
#  (',', '.'),
#  ('we', 'PRON'),
#  ('can', 'VERB'),
#  ('change', 'VERB'),
#  ('the', 'DET'),
#  ('midi', 'NOUN'),
#  ('messages', 'VERB'),
#  ('we', 'PRON'),
#  ('are', 'VERB'),
#  ('receiving', 'VERB'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('use', 'VERB'),
#  ('them', 'PRON'),
#  ('for', 'ADP'),
#  ('different', 'ADJ'),
#  ('plugins', 'NOUN'),
#  ('.', '.'),
#  ('in', 'ADP'),
#  ('this', 'DET'),
#  ('board', 'NOUN'),
#  (',', '.'),
#  ('we', 'PRON'),
#  ('duplicate', 'VERB'),
#  ('cc14', 'NOUN'),
#  ('to', 'PRT'),
#  ('cc44', 'VERB'),
#  ('to', 'PRT'),
#  ('control', 'VERB'),
#  ('two', 'NUM'),
#  ('parameters', 'NOUN'),
#  ('at', 'ADP'),
#  ('once', 'ADV'),
#  ('(', '.'),
#  ('width', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('pingpong', 'ADJ'),
#  ('panner', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('depth', 'NOUN'),
#  ('of', 'ADP'),
#  ('shiro', 'ADJ'),
#  ('harmless', 'NOUN'),
#  (')', '.'),
#  ('.', '.'),
#  ('we', 'PRON'),
#  ('also', 'ADV'),
#  ('transpose', 'VERB'),
#  ('the', 'DET'),
#  ('note', 'NOUN'),
#  ('an', 'DET'),
#  ('octave', 'VERB'),
#  ('down', 'PRT'),
#  ('and', 'CONJ'),
#  ('an', 'DET'),
#  ('octave', 'VERB'),
#  ('up', 'PRT'),
#  ('.', '.'),
#  ('try', 'VERB'),
#  ('it', 'PRON'),
#  ('out', 'PRT'),
#  ('and', 'CONJ'),
#  ('get', 'VERB'),
#  ('creative', 'ADJ'),
#  ('!', '.'),
#  ('shine', 'NOUN'),
#  ('playing', 'VERB'),
#  ('a', 'DET'),
#  ('bass', 'NOUN'),
#  ('patch', 'NOUN'),
#  ('with', 'ADP'),
#  ('optional', 'ADJ'),
#  ('+3/-3', 'NOUN'),
#  (',', '.'),
#  ('close', 'ADV'),
#  ('to', 'PRT'),
#  ('``', '.'),
#  ('shine', 'VERB'),
#  ("''", '.'),
#  ('by', 'ADP'),
#  ('``', '.'),
#  ('the', 'DET'),
#  ('cool', 'ADJ'),
#  ('quest', 'NOUN'),
#  ("''", '.'),
#  ('.', '.'),
#  ('mods', 'NOUN'),
#  ('cpu', 'VERB'),
#  ('at', 'ADP'),
#  ('it', 'PRON'),
#  ("'s", 'VERB'),
#  ('max', 'ADJ'),
#  (':', '.'),
#  (')', '.'),
#  ('money', 'NOUN'),
#  ('for', 'ADP'),
#  ('something', 'NOUN'),
#  ('first', 'ADJ'),
#  ('try', 'NOUN'),
#  ('with', 'ADP'),
#  ('modduo', 'NOUN'),
#  ('.', '.'),
#  ('i', 'VERB'),
#  ('tried', 'VERB'),
#  ('to', 'PRT'),
#  ('get', 'VERB'),
#  ('a', 'DET'),
#  ('kind', 'NOUN'),
#  ('of', 'ADP'),
#  ('``', '.'),
#  ('money', 'NOUN'),
#  ('for', 'ADP'),
#  ('nothing', 'NOUN'),
#  ("''", '.'),
#  ('tone', 'NOUN'),
#  ('.', '.'),
#  ('intended', 'VERB'),
#  ('for', 'ADP'),
#  ('headphones', 'NOUN'),
#  ('output', 'NOUN'),
#  (':', '.'),
#  ('i', 'NOUN'),
#  ('hav', 'VERB'),
#  ("n't", 'ADV'),
#  ('tried', 'VERB'),
#  ('on', 'ADP'),
#  ('a', 'DET'),
#  ('real', 'ADJ'),
#  ('amp', 'NOUN'),
#  ('.', '.'),
#  ('gxjcm800test', 'VERB'),
#  ('just', 'ADV'),
#  ('a', 'DET'),
#  ('short', 'ADJ'),
#  ('test', 'NOUN'),
#  ('od-leslie', 'NOUN'),
#  ('organ', 'NOUN'),
#  ('player', 'NOUN'),
#  ('ca', 'VERB'),
#  ("n't", 'ADV'),
#  ('make', 'VERB'),
#  ('the', 'DET'),
#  ('gig', 'NOUN'),
#  ('?', '.'),
#  ('no', 'DET'),
#  ('midi', 'NOUN'),
#  ('keyboard', 'ADV'),
#  ('?', '.'),
#  ('no', 'DET'),
#  ('problem', 'NOUN'),
#  ('!', '.'),
#  ('mod', 'NOUN'),
#  ('duo', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('rescue', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('setbfree', 'ADJ'),
#  ("'whirl", 'NOUN'),
#  ("'", 'PRT'),
#  ('speaker', 'NOUN'),
#  ('leslie', 'VERB'),
#  ('emulation', 'NOUN'),
#  ('.', '.'),
#  ('to', 'PRT'),
#  ('fake', 'VERB'),
#  ('organ', 'ADJ'),
#  ('sounds', 'NOUN'),
#  ('roll', 'VERB'),
#  ('back', 'ADV'),
#  ('the', 'DET'),
#  ('tone', 'NOUN'),
#  ('on', 'ADP'),
#  ('your', 'PRON'),
#  ('rhythm', 'NOUN'),
#  ('pickup', 'NOUN'),
#  ('and', 'CONJ'),
#  ('play', 'VERB'),
#  ('fingerstyle', 'ADJ'),
#  ('with', 'ADP'),
#  ('lots', 'NOUN'),
#  ('of', 'ADP'),
#  ('high', 'ADJ'),
#  ('drone', 'NOUN'),
#  ('notes', 'NOUN'),
#  ('.', '.'),
#  ('do', 'VERB'),
#  ("n't", 'ADV'),
#  ('forget', 'VERB'),
#  ('if', 'ADP'),
#  ('you', 'PRON'),
#  ('do', 'VERB'),
#  ('have', 'VERB'),
#  ('a', 'DET'),
#  ('midi', 'ADJ'),
#  ('keyboard', 'NOUN'),
#  ('you', 'PRON'),
#  ('can', 'VERB'),
#  ('emulate', 'VERB'),
#  ('the', 'DET'),
#  ('real', 'ADJ'),
#  ('hammond', 'NOUN'),
#  ('b3', 'ADJ'),
#  ('thing', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('setbfree', 'ADJ'),
#  ('organ', 'NOUN'),
#  ('generator', 'NOUN'),
#  (',', '.'),
#  ('this', 'DET'),
#  ('pedalboard', 'NOUN'),
#  ('is', 'VERB'),
#  ('for', 'ADP'),
#  ('faking', 'VERB'),
#  ('it', 'PRON'),
#  ('with', 'ADP'),
#  ('a', 'DET'),
#  ('guitar', 'NOUN'),
#  ('.', '.'),
#  ('harmless', 'ADJ'),
#  ('jcm', 'NOUN'),
#  ('trying', 'VERB'),
#  ('out', 'PRT'),
#  ('the', 'DET'),
#  ('jcm-800', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('shiro', 'NOUN'),
#  ('harmless', 'NOUN'),
#  ('modulator', 'NOUN'),
#  ('.', '.'),
#  ('such', 'DET'),
#  ('a', 'DET'),
#  ('beautiful', 'ADJ'),
#  ('sound', 'NOUN'),
#  ('!', '.'),
#  ('!', '.'),
#  ('!', '.'),
#  ('uoyhtiw', 'ADJ'),
#  ('experiments', 'NOUN'),
#  ('with', 'ADP'),
#  ('sequencers', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('voice', 'NOUN'),
#  ('.', '.'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('arms', 'NOUN'),
#  ('of', 'ADP'),
#  ('ac30', 'NOUN'),
#  (',', '.'),
#  ('delay', 'NOUN'),
#  (',', '.'),
#  ('reverbs', 'NOUN'),
#  ('!', '.'),
#  ('the', 'DET'),
#  ('knifes', 'ADJ'),
#  ('reverbery', 'NOUN'),
#  ('ac30', 'NOUN'),
#  ('and', 'CONJ'),
#  ('jcm', 'NOUN'),
#  ('.', '.'),
#  ('+', 'VERB'),
#  ('having', 'VERB'),
#  ('fun', 'NOUN'),
#  ('with', 'ADP'),
#  ('whammied', 'ADJ'),
#  ('voice', 'NOUN'),
#  ('(', '.'),
#  ('like', 'ADP'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('knife', 'NOUN'),
#  (';', '.'),
#  (')', '.'),
#  (')', '.'),
#  ('midistuffdemo', 'NOUN'),
#  ('just', 'ADV'),
#  ('an', 'DET'),
#  ('experiment', 'ADJ'),
#  ('synthesizers', 'NOUN'),
#  ('can', 'VERB'),
#  ('make', 'VERB'),
#  ('music', 'NOUN'),
#  ('first', 'ADJ'),
#  ('attempt', 'NOUN'),
#  ('with', 'ADP'),
#  ('synthesizers', 'NOUN'),
#  ('and', 'CONJ'),
#  ('keyboard', 'NOUN'),
#  ('on', 'ADP'),
#  ('mod', 'NOUN'),
#  ('duo', 'NOUN'),
#  ('.', '.'),
#  ('i', 'ADJ'),
#  ('think', 'VERB'),
#  ('i', 'NOUN'),
#  ('found', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('favorite', 'ADJ'),
#  ('thing', 'NOUN'),
#  ('.', '.'),
#  ('shimmermachine', 'NOUN'),
#  ('using', 'VERB'),
#  ('the', 'DET'),
#  ('new', 'ADJ'),
#  ('harmless', 'NOUN'),
#  ('by', 'ADP'),
#  ('shiro', 'NOUN'),
#  (',', '.'),
#  ('combined', 'VERB'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('larynx', 'NOUN'),
#  ('on', 'ADP'),
#  ('my', 'PRON'),
#  ('novation', 'NOUN'),
#  ('circuit', 'NOUN'),
#  ('.', '.'),
#  ('also', 'ADV'),
#  ('using', 'VERB'),
#  ('the', 'DET'),
#  ('new', 'ADJ'),
#  ('guitarix', 'NOUN'),
#  ('vibrochump', 'NOUN'),
#  (',', '.'),
#  ('spiced', 'VERB'),
#  ('up', 'PRT'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('tap', 'NOUN'),
#  ('tubewarmth', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('warmer', 'NOUN'),
#  ('sound', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('shiroverbs', 'NOUN'),
#  ('are', 'VERB'),
#  ('set', 'VERB'),
#  ('to', 'PRT'),
#  ('octave', 'VERB'),
#  ('down', 'PRT'),
#  ('and', 'CONJ'),
#  ('octave', 'VERB'),
#  ('up', 'PRT'),
#  ('for', 'ADP'),
#  ('very', 'ADV'),
#  ('different', 'ADJ'),
#  ('shimmer', 'NOUN'),
#  ('sounds', 'NOUN'),
#  ('.', '.'),
#  ('loop', 'NOUN'),
#  ('+', 'ADJ'),
#  ('harmonicos', 'NOUN'),
#  ('acostumando', 'NOUN'),
#  ('com', 'NOUN'),
#  ('o', 'NOUN'),
#  ('loop', 'NOUN'),
#  (',', '.'),
#  ('da', 'NOUN'),
#  ('pra', 'NOUN'),
#  ('fazer', 'NOUN'),
#  ('muita', 'ADJ'),
#  ('coisa', 'NOUN'),
#  ('com', 'NOUN'),
#  ('isso', 'NOUN'),
#  ('...', '.'),
#  ('.lindo', 'NOUN'),
#  ('!', '.'),
#  ('musica', 'NOUN'),
#  ('segredos', 'X'),
#  ('-', '.'),
#  ('trem', 'NOUN'),
#  ('de', 'ADP'),
#  ('carga', 'X'),
#  ('circuitjam', 'NOUN'),
#  ('i', 'NOUN'),
#  ("'m", 'VERB'),
#  ('using', 'VERB'),
#  ('the', 'DET'),
#  ('novation', 'NOUN'),
#  ('circuit', 'NOUN'),
#  ('as', 'ADP'),
#  ('a', 'DET'),
#  ('midi-controller', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('mod', 'NOUN'),
#  ('duo', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('duo', 'NOUN'),
#  ('has', 'VERB'),
#  ('great', 'ADJ'),
#  ('midi-filtering', 'ADJ'),
#  ('capabilities', 'NOUN'),
#  (',', '.'),
#  ('so', 'ADP'),
#  ('i', 'ADJ'),
#  ('filtered', 'VERB'),
#  ('the', 'DET'),
#  ('individual', 'NOUN'),
#  ('sequenced', 'VERB'),
#  ('tracks', 'NOUN'),
#  ('and', 'CONJ'),
#  ('hooked', 'VERB'),
#  ('them', 'PRON'),
#  ('up', 'PRT'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('drummachine', 'NOUN'),
#  (',', '.'),
#  ('bass-synth', 'ADJ'),
#  ('and', 'CONJ'),
#  ('e-piano', 'ADJ'),
#  ('.', '.'),
#  ('epic', 'NOUN'),
#  ('strummed', 'VERB'),
#  ('synth', 'ADJ'),
#  ('great', 'ADJ'),
#  ('for', 'ADP'),
#  ('testing', 'VERB'),
#  ('speakers', 'NOUN'),
#  ('because', 'ADP'),
#  ('it', 'PRON'),
#  ('generates', 'VERB'),
#  ('an', 'DET'),
#  ('extremely', 'ADV'),
#  ('wide', 'ADJ'),
#  ('range', 'NOUN'),
#  ('of', 'ADP'),
#  ('frequencies', 'NOUN'),
#  ('.', '.'),
#  ('sit', 'NOUN'),
#  ('on', 'ADP'),
#  ('your', 'PRON'),
#  ('subwoofer', 'NOUN'),
#  ('.', '.'),
#  ('cottonmouth', 'NOUN'),
#  ('lives', 'VERB'),
#  ('the', 'DET'),
#  ('pedal', 'ADJ'),
#  ('combination', 'NOUN'),
#  ('of', 'ADP'),
#  ('chorus/flanger', 'NOUN'),
#  ('and', 'CONJ'),
#  ('cabinet', 'NOUN'),
#  ('give', 'VERB'),
#  ('a', 'DET'),
#  ('warm', 'NOUN'),
#  (',', '.'),
#  ('thick', 'ADJ'),
#  ('distortion', 'NOUN'),
#  ('while', 'ADP'),
#  ('still', 'ADV'),
#  ('leaving', 'VERB'),
#  ('space', 'NOUN'),
#  ('for', 'ADP'),
#  ('lingering', 'VERB'),
#  ('frequencies', 'NOUN'),
#  ('to', 'PRT'),
#  ('fit', 'VERB'),
#  ('amongst', 'ADP'),
#  ('the', 'DET'),
#  ('deep', 'ADJ'),
#  ('low', 'ADJ'),
#  ('end', 'NOUN'),
#  ('.', '.'),
#  ('i', 'NOUN'),
#  ('mostly', 'ADV'),
#  ('recently', 'ADV'),
#  ('used', 'VERB'),
#  ('this', 'DET'),
#  ('pedalboard', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('song', 'NOUN'),
#  ('with', 'ADP'),
#  ('rj', 'NOUN'),
#  ('thyme', 'NOUN'),
#  ('.', '.'),
#  ('check', 'VERB'),
#  ('it', 'PRON'),
#  ('out', 'PRT'),
#  ('below', 'ADP'),
#  (':', '.'),
#  ('https', 'NOUN'),
#  (':', '.'),
#  ('//soundcloud.com/rjthyme/god-is-music-feat-klaas-von-karlos', 'ADJ'),
#  ('od-octave', 'ADJ'),
#  ('i', 'NOUN'),
#  ('was', 'VERB'),
#  ('looking', 'VERB'),
#  ('to', 'PRT'),
#  ('emulate', 'VERB'),
#  ('my', 'PRON'),
#  ('boss', 'ADP'),
#  ('oc-3', 'ADJ'),
#  ('pedal', 'NOUN'),
#  ('which', 'DET'),
#  ('features', 'VERB'),
#  ('both', 'DET'),
#  ('octave', 'ADJ'),
#  ('and', 'CONJ'),
#  ('fuzz', 'NOUN'),
#  (',', '.'),
#  ('i', 'NOUN'),
#  ('tried', 'VERB'),
#  ('the', 'DET'),
#  ('mod', 'NOUN'),
#  ('guitarix', 'VERB'),
#  ('oc-2', 'ADJ'),
#  ('emulation', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('mod', 'ADJ'),
#  ('mda-subsynth', 'ADJ'),
#  ('but', 'CONJ'),
#  ('both', 'DET'),
#  ('were', 'VERB'),
#  ('pretty', 'ADV'),
#  ('messy', 'ADJ'),
#  ('and', 'CONJ'),
#  ('lost', 'VERB'),
#  ('tracking', 'VERB'),
#  ('pretty', 'ADV'),
#  ('quickly', 'ADV'),
#  ('especially', 'ADV'),
#  ('when', 'ADV'),
#  ('playing', 'VERB'),
#  ('fast', 'ADV'),
#  ('.', '.'),
#  ('i', 'NOUN'),
#  ('was', 'VERB'),
#  ('able', 'ADJ'),
#  ('to', 'PRT'),
#  ('utilize', 'VERB'),
#  ('the', 'DET'),
#  ('2voices', 'NUM'),
#  ('plugin', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('tubescreamer', 'NOUN'),
#  ('and', 'CONJ'),
#  ('get', 'VERB'),
#  ('a', 'DET'),
#  ('righteous', 'ADJ'),
#  ('octave', 'NOUN'),
#  ('fuzz', 'NOUN'),
#  ('that', 'DET'),
#  ('tracks', 'VERB'),
#  ('nicely', 'ADV'),
#  ('.', '.'),
#  ('2voices', 'NUM'),
#  ('is', 'VERB'),
#  ('set', 'VERB'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ("'step1", 'NOUN'),
#  ("'", 'PRT'),
#  ('dropped', 'VERB'),
#  ('an', 'DET'),
#  ('octave', 'NOUN'),
#  ('and', 'CONJ'),
#  ('step2', 'NOUN'),
#  ('retains', 'VERB'),
#  ('the', 'DET'),
#  ('original', 'ADJ'),
#  ('actual', 'ADJ'),
#  ('pitch', 'NOUN'),
#  ('.', '.'),
#  ('unfortunately', 'ADV'),
#  ('there', 'DET'),
#  ('was', 'VERB'),
#  ('not', 'ADV'),
#  ('enough', 'ADJ'),
#  ('spare', 'ADJ'),
#  ('cpu', 'NOUN'),
#  ('to', 'PRT'),
#  ('record', 'VERB'),
#  ('a', 'DET'),
#  ('sample', 'NOUN'),
#  ('.', '.'),
#  ('endless', 'ADJ'),
#  ('feed', 'NOUN'),
#  ('this', 'DET'),
#  ('patch', 'NOUN'),
#  ('seconds', 'VERB'),
#  ('of', 'ADP'),
#  ('signal', 'NOUN'),
#  ('and', 'CONJ'),
#  ('enjoy', 'VERB'),
#  ('it', 'PRON'),
#  ('for', 'ADP'),
#  ('hours', 'NOUN'),
#  ('.', '.'),
#  ('set', 'VERB'),
#  ('up', 'PRT'),
#  ('as', 'ADP'),
#  ('a', 'DET'),
#  ('send', 'ADJ'),
#  ('effect', 'NOUN'),
#  ('.', '.'),
#  ('deep', 'ADV'),
#  ('well', 'ADV'),
#  ('a', 'DET'),
#  ('kind', 'NOUN'),
#  ('of', 'ADP'),
#  ('maximalistic', 'ADJ'),
#  ('reverb', 'NOUN'),
#  ('.', '.'),
#  ('set', 'VERB'),
#  ('up', 'PRT'),
#  ('as', 'ADP'),
#  ('a', 'DET'),
#  ('send', 'ADJ'),
#  ('effect', 'NOUN'),
#  ('.', '.'),
#  ('above', 'ADP'),
#  ('our', 'PRON'),
#  ('heads', 'NOUN'),
#  ('voices', 'NOUN'),
#  ('from', 'ADP'),
#  ('somewhere', 'ADV'),
#  ('above', 'ADP'),
#  ('our', 'PRON'),
#  ('heads', 'NOUN'),
#  ('pick', 'VERB'),
#  ('up', 'PRT'),
#  ('your', 'PRON'),
#  ('signal', 'NOUN'),
#  ('and', 'CONJ'),
#  ('sing', 'VERB'),
#  ('with', 'ADP'),
#  ('you', 'PRON'),
#  ('.', '.'),
#  (';', '.'),
#  (')', '.'),
#  ('set', 'VERB'),
#  ('up', 'PRT'),
#  ('as', 'ADP'),
#  ('a', 'DET'),
#  ('send', 'ADJ'),
#  ('effect', 'NOUN'),
#  ('.', '.'),
#  ('chorus', 'NOUN'),
#  ('maniac', 'NOUN'),
#  ('(', '.'),
#  ('clean', 'ADJ'),
#  ('funk', 'NOUN'),
#  ('gtr', 'NOUN'),
#  (')', '.'),
#  ('clean', 'NOUN'),
#  ('sounds', 'VERB'),
#  ('for', 'ADP'),
#  ('rhythm', 'NOUN'),
#  ('guitar', 'NOUN'),
#  ('.', '.'),
#  ('in', 'ADP'),
#  ('this', 'DET'),
#  ('one', 'NUM'),
#  ('i', 'NOUN'),
#  ('added', 'VERB'),
#  ('a', 'DET'),
#  ('little', 'ADJ'),
#  ('bit', 'NOUN'),
#  ('of', 'ADP'),
#  ('compression', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('dry', 'ADJ'),
#  ('signal', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('gain', 'NOUN'),
#  ('control', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('chorus', 'NOUN'),
#  ('signal', 'NOUN'),
#  ('.', '.'),
#  ('http', 'NOUN'),
#  (':', '.'),
#  ('//www.rogeriocouto.com.br', 'ADJ'),
#  ('chorus', 'NOUN'),
#  ('maniac', 'ADJ'),
#  ('klean', 'ADJ'),
#  ('aula', 'NOUN'),
#  ('#', '.'),
#  ('1', 'NUM'),
#  ('a', 'DET'),
#  ('clean', 'ADJ'),
#  ('patch', 'NOUN'),
#  ('with', 'ADP'),
#  ('some', 'DET'),
#  ('nice', 'ADJ'),
#  ('reverb', 'NOUN'),
#  ('.', '.'),
#  ('pink', 'VERB'),
#  ('floyd', 'ADJ'),
#  ('-', '.'),
#  ('shine', 'NOUN'),
#  ('on', 'ADP'),
#  ('you', 'PRON'),
#  ('crazy', 'VERB'),
#  ('diamond', 'NOUN'),
#  ('i', 'NOUN'),
#  ('tried', 'VERB'),
#  ('as', 'ADV'),
#  ('much', 'ADJ'),
#  ('as', 'ADP'),
#  ('possible', 'ADJ'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('sound', 'NOUN'),
#  ('mixer', 'NOUN'),
#  (',', '.'),
#  ('reverb', 'NOUN'),
#  ('and', 'CONJ'),
#  ('click', 'NOUN'),
#  ('[', 'NOUN'),
#  ('rogeriocouto.com.br', 'VERB'),
#  (']', 'NOUN'),
#  ('just', 'ADV'),
#  ('a', 'DET'),
#  ('some', 'DET'),
#  ('tools', 'NOUN'),
#  ('to', 'PRT'),
#  ('use', 'VERB'),
#  ('with', 'ADP'),
#  ('my', 'PRON'),
#  ('students', 'NOUN'),
#  ('c', 'VERB'),
#  ('major', 'ADJ'),
#  ('accompaniment', 'NOUN'),
#  ('fun', 'NOUN'),
#  ('with', 'ADP'),
#  ('step-sequencer', 'ADJ'),
#  ('&', 'CONJ'),
#  ('midi', 'NOUN'),
#  ('utils', 'NOUN'),
#  ('--', '.'),
#  ('jam', 'NOUN'),
#  ('along', 'ADP'),
#  ('mod', 'NOUN'),
#  ('on', 'ADP'),
#  ...]

# %% [markdown]
# ## Análise

# %%
tag_frequence_dist = nltk.FreqDist(tag for (word, tag) in taggs)

tag_frequence_dist.most_common()

#for common, total in tag_frequence_dist.most_common():
#    nltk.help.upenn_tagset(common)
# Out:
# [('NOUN', 1256),
#  ('VERB', 516),
#  ('ADJ', 471),
#  ('.', 467),
#  ('DET', 423),
#  ('ADP', 376),
#  ('ADV', 130),
#  ('CONJ', 124),
#  ('PRT', 112),
#  ('PRON', 94),
#  ('NUM', 84),
#  ('X', 10)]

# %%
from collections import Counter

def details(words, tag, frequence_dist):
    words_tag = filter_words(words, tag)
    
    print(tag + ':')
    print(' - unique', len(Counter(words_tag).most_common()))
    print(' - total', frequence_dist[tag])
    print(' - most common', Counter(words_tag).most_common(25))

def filter_words(words, tag):
    return [word for (word, t) in words if t == tag]

details(taggs, 'NOUN', tag_frequence_dist)
details(taggs, 'VERB', tag_frequence_dist)
details(taggs, 'ADJ', tag_frequence_dist)
# Out:
# NOUN:
#  - unique 568
#  - total 1256
#  - most common [('guitar', 41), ('mod', 28), ('sound', 23), ('i', 20), ('bass', 17), ('pedalboard', 17), ('loop', 16), ('tone', 14), ('delay', 14), ('reverb', 14), ('caps', 13), ('midi', 11), ('side', 11), ('cabinet', 11), ('sounds', 11), ('instruments', 10), ('space', 10), ('channel', 10), ('effects', 9), ('amp', 9), ('effect', 8), ('patch', 8), ('stefan', 8), ('floor', 8), ('elevator', 8)]
# VERB:
#  - unique 264
#  - total 516
#  - most common [('is', 26), ('using', 22), ('can', 11), ("'s", 9), ('made', 9), ('get', 9), ('do', 7), ('used', 7), ('has', 7), ('octave', 6), ('make', 6), ('setting', 5), ('use', 5), ('set', 5), ('playing', 5), ('looped', 5), ('have', 5), ('i', 5), ('tried', 5), ('was', 5), ('show', 5), ('added', 5), ('sounds', 5), ('ca', 4), ('looping', 4)]
# ADJ:
#  - unique 261
#  - total 471
#  - most common [('clean', 29), ('basic', 21), ('nice', 12), ('simple', 10), ('acoustic', 10), ('aka', 8), ('i', 8), ('first', 8), ('great', 7), ('big', 6), ('good', 6), ('different', 5), ('new', 5), ('dry', 5), ('little', 5), ('unfiltered', 4), ('cool', 4), ('synth', 4), ('real', 4), ('lead', 4), ('overdrive', 4), ('send', 3), ('crunchy', 3), ('low', 3), ('open', 3)]

# %% [markdown]
# Probabilidade de uma palavra ser a escolhida com base no grupo e na quantidade

# %%
Counter(filter_words(taggs, 'NOUN')).most_common()
#manual_words = [
#    'guitar', 'bass', 'loop', 'tone', 'delay', 'reverb', 'midi', 'cabinet', 'space', 'amp', 'loop', 'clean'
#]
# Out:
# [('guitar', 41),
#  ('mod', 28),
#  ('sound', 23),
#  ('i', 20),
#  ('bass', 17),
#  ('pedalboard', 17),
#  ('loop', 16),
#  ('tone', 14),
#  ('delay', 14),
#  ('reverb', 14),
#  ('caps', 13),
#  ('midi', 11),
#  ('side', 11),
#  ('cabinet', 11),
#  ('sounds', 11),
#  ('instruments', 10),
#  ('space', 10),
#  ('channel', 10),
#  ('effects', 9),
#  ('amp', 9),
#  ('effect', 8),
#  ('patch', 8),
#  ('stefan', 8),
#  ('floor', 8),
#  ('elevator', 8),
#  ('chorus', 8),
#  ('akke', 8),
#  ('cowboys', 8),
#  ('people', 8),
#  ('pedal', 8),
#  ('olaf', 8),
#  ('ambience', 7),
#  ('synth', 6),
#  ('distortion', 6),
#  ('fuzz', 6),
#  ('duo', 6),
#  ('pickup', 6),
#  ('setup', 6),
#  ('+', 6),
#  ('tube', 6),
#  ('models', 5),
#  ('metal', 5),
#  ('gain', 5),
#  ('pedals', 5),
#  ('notes', 5),
#  ('board', 5),
#  ('pitch', 5),
#  ('output', 5),
#  ('signal', 5),
#  ('end', 5),
#  ('beat', 5),
#  ('phaser', 5),
#  ('volume', 5),
#  ('voice', 5),
#  ('melody', 5),
#  ('way', 5),
#  ('shimmer', 4),
#  ('chain', 4),
#  ('lots', 4),
#  ('crunch', 4),
#  ('ac30', 4),
#  ('whammy', 4),
#  ('sample', 4),
#  ('ampvts', 4),
#  ('muff', 4),
#  ('looper', 4),
#  ('fun', 4),
#  ('ns/stick', 4),
#  ('iv', 4),
#  ('delays', 4),
#  ('background', 4),
#  ('layers', 4),
#  ('response', 3),
#  ('octave', 3),
#  ('controls', 3),
#  ('generator', 3),
#  ('parallel', 3),
#  ('https', 3),
#  ('input', 3),
#  ('switches', 3),
#  ('harmless', 3),
#  ('rain', 3),
#  ('speaker', 3),
#  ('taste', 3),
#  ('cab', 3),
#  ('solos', 3),
#  ('click', 3),
#  ('screamer', 3),
#  ('version', 3),
#  ('clean', 3),
#  ('emulation', 3),
#  ('rhythm', 3),
#  ('wah', 3),
#  ('pad', 3),
#  ('layer', 3),
#  ('quack', 3),
#  ('jamming', 3),
#  ('bit', 3),
#  ('[', 3),
#  ('neck', 3),
#  ('cc', 3),
#  ('shiro', 3),
#  ('time', 3),
#  ('drums', 3),
#  ('strat', 3),
#  ('power', 3),
#  ('feedback', 3),
#  ('control', 2),
#  ('shine', 2),
#  ('waveform', 2),
#  ('song', 2),
#  ('impala', 2),
#  ('swell', 2),
#  ('filter', 2),
#  ('recording', 2),
#  ('crunchy', 2),
#  ('jx10', 2),
#  ('gibson', 2),
#  ('mix', 2),
#  ('sine', 2),
#  ('channels', 2),
#  ('synthesizers', 2),
#  (']', 2),
#  ('something', 2),
#  ('novation', 2),
#  ('pitch-shifters', 2),
#  ('%', 2),
#  ('parameters', 2),
#  ('beatbox', 2),
#  ('noise', 2),
#  ('jcm-800', 2),
#  ('drone', 2),
#  ('kind', 2),
#  ('team', 2),
#  ('eq', 2),
#  ('square', 2),
#  ('liveloop', 2),
#  ('rest', 2),
#  ('line', 2),
#  ('lead', 2),
#  ('bleepy', 2),
#  ('diego', 2),
#  ('shiroverb', 2),
#  ('epiano', 2),
#  ('footswitches', 2),
#  ('middle', 2),
#  ('gianfranco', 2),
#  ('preset', 2),
#  ('fx', 2),
#  ('organ', 2),
#  ('attempt', 2),
#  ('auto', 2),
#  ('subwoofer', 2),
#  ('simulation', 2),
#  ('rhodes', 2),
#  ('trio', 2),
#  ('plugins', 2),
#  ('circuit', 2),
#  ('jcm', 2),
#  ('2voices', 2),
#  ('simulator', 2),
#  ('use', 2),
#  ('drive', 2),
#  ('gx', 2),
#  ('thing', 2),
#  ('semitones', 2),
#  ('cpu', 2),
#  ('report', 2),
#  ('adjusts', 2),
#  ('pickups', 2),
#  ('timbre', 2),
#  ('modulay', 2),
#  ('keyboard', 2),
#  ('compression', 2),
#  ('drumming', 2),
#  ('tremolo', 2),
#  ('my-rhodes', 2),
#  ('drummachine', 2),
#  ('tap', 2),
#  ('sustainer', 2),
#  ('tonestack', 2),
#  ('com', 2),
#  ('playing', 2),
#  ('fullness', 2),
#  ('headphones', 2),
#  ('sequencer', 2),
#  ('drum', 2),
#  ('mullet', 2),
#  ('note', 2),
#  ('voices', 2),
#  ('frequencies', 2),
#  ('tilt', 2),
#  ('trumpet/range', 2),
#  ('improvisation', 2),
#  ('gen', 2),
#  ('cut', 2),
#  ('settings', 2),
#  ('tubescreamer', 2),
#  ('money', 2),
#  ('depth', 2),
#  ('heads', 2),
#  ('wahbass', 1),
#  ('feed', 1),
#  ('connect', 1),
#  ("'step1", 1),
#  ('cap', 1),
#  ('upfront', 1),
#  ('single-coil', 1),
#  ('freakverb', 1),
#  ('mcclane', 1),
#  ('button', 1),
#  ('shimmer/swell', 1),
#  ('crossx3', 1),
#  ('emphasis', 1),
#  ('today', 1),
#  ('blend', 1),
#  ('cleanamp', 1),
#  ("'this", 1),
#  ('step2', 1),
#  ('shoutout', 1),
#  ('maxx', 1),
#  ('loopverb', 1),
#  ('setting', 1),
#  ('rev2', 1),
#  ('lot', 1),
#  ('tubewarmth', 1),
#  ('track', 1),
#  ('vol', 1),
#  ('acostumando', 1),
#  ('die', 1),
#  ('mda', 1),
#  ('impact', 1),
#  ('demo', 1),
#  ('harrdcore', 1),
#  ('entropy', 1),
#  ('makeshift', 1),
#  ('knife', 1),
#  ('quacking', 1),
#  ('utils', 1),
#  ('trumpet/volume', 1),
#  ('thickness', 1),
#  ('fishman', 1),
#  ('x2n', 1),
#  ('pumpkins', 1),
#  ('sc', 1),
#  ('attack', 1),
#  ('usage', 1),
#  ('g2m', 1),
#  ('split', 1),
#  ('larynx', 1),
#  ('transitions', 1),
#  ('pure', 1),
#  ('nothing', 1),
#  ('jazz', 1),
#  ('foot', 1),
#  ('artifacts', 1),
#  ('soundtrack', 1),
#  ('phat', 1),
#  ('tools', 1),
#  ('dry', 1),
#  ('cool', 1),
#  ('fine', 1),
#  ('percussions', 1),
#  ('simple', 1),
#  ('overkill', 1),
#  ('combination', 1),
#  ('issues', 1),
#  ('hail', 1),
#  ('things', 1),
#  ('korg', 1),
#  ('style', 1),
#  ('toffee', 1),
#  ('phase', 1),
#  ('tracks', 1),
#  ('gigs', 1),
#  ('talent', 1),
#  ('students', 1),
#  ('click+beatbox', 1),
#  ('guit', 1),
#  ('kemper', 1),
#  ('backtoschooljamm', 1),
#  ('pregain', 1),
#  ('sounding', 1),
#  ('change', 1),
#  ('search', 1),
#  ('knobs', 1),
#  ('soundscapes', 1),
#  ('spacechurch', 1),
#  ('capabilities', 1),
#  ('reverbery', 1),
#  ('berlinjamm00:30', 1),
#  ('x42', 1),
#  ('city', 1),
#  ('crackle', 1),
#  ('tame', 1),
#  ('bernie', 1),
#  ('moog', 1),
#  ('on/off', 1),
#  ('sense', 1),
#  ('sonuus', 1),
#  ('responses', 1),
#  ("'shimmer", 1),
#  ('es', 1),
#  ('rescue', 1),
#  ('rj', 1),
#  ('w/', 1),
#  ('fazer', 1),
#  ('boosters', 1),
#  ('shiroverbs', 1),
#  ('tribute', 1),
#  ('yesterday', 1),
#  ('coisa', 1),
#  ('mutes', 1),
#  ('palm', 1),
#  ('da', 1),
#  ('trick', 1),
#  ('shimmermachine', 1),
#  ('speakers', 1),
#  ('diamond', 1),
#  ('lyrics', 1),
#  ('ahhhs', 1),
#  ('perfect', 1),
#  ('try', 1),
#  ('warmer', 1),
#  ('vibes', 1),
#  ('hence', 1),
#  ('musica', 1),
#  ('gtr', 1),
#  ('aula', 1),
#  ('melodie', 1),
#  ('backing', 1),
#  ('loopback', 1),
#  ('access', 1),
#  ('trumpet/windnoise', 1),
#  ('base', 1),
#  ('basichardcore', 1),
#  ('drop', 1),
#  ('size', 1),
#  ('room', 1),
#  ('p90', 1),
#  ('sub-bass', 1),
#  ('head', 1),
#  ('amount', 1),
#  ('clipping', 1),
#  ('slowgear', 1),
#  ('blues', 1),
#  ('feel', 1),
#  ('trem', 1),
#  ('section', 1),
#  ('keys', 1),
#  ('instance', 1),
#  ('hours', 1),
#  ('shift', 1),
#  ('stages', 1),
#  ('rogeriocouto.com.br', 1),
#  ('suite', 1),
#  ('swells', 1),
#  ('glitch', 1),
#  ('morning', 1),
#  ('chorus/flanger', 1),
#  ('mods', 1),
#  ('double', 1),
#  ('midi-split', 1),
#  ('front', 1),
#  ('autowah', 1),
#  ('sequencers', 1),
#  ('register', 1),
#  ('reverbs', 1),
#  ('kvk', 1),
#  ('http', 1),
#  ('maniac', 1),
#  ('stereo', 1),
#  ('louder-harder-faster', 1),
#  ('redo', 1),
#  ('mode', 1),
#  ('cabinets', 1),
#  ('reminiscent', 1),
#  ('prefreak', 1),
#  ('clicks', 1),
#  ('mixer', 1),
#  ('semitone', 1),
#  ('glitchy', 1),
#  ('sorrow', 1),
#  ('pull', 1),
#  ('test', 1),
#  ('issue', 1),
#  ('disclaimer', 1),
#  ('fm', 1),
#  ('sunday', 1),
#  ('modulator', 1),
#  ('hey', 1),
#  ('ds', 1),
#  ('panner', 1),
#  ('sond', 1),
#  ('improvising', 1),
#  ('cottonmouth', 1),
#  ('type', 1),
#  ('post', 1),
#  ('trumpet/formants', 1),
#  ('chords', 1),
#  ('undo/redo', 1),
#  ('.lindo', 1),
#  ('boogie', 1),
#  ('midi-controller', 1),
#  ('trumpet', 1),
#  ('ohhhs', 1),
#  ('everything', 1),
#  ('riff', 1),
#  ('guitarix', 1),
#  ('path', 1),
#  ('ol', 1),
#  ('trem/env/chs', 1),
#  ('load', 1),
#  ('riffs', 1),
#  ('crossover', 1),
#  ('hb', 1),
#  ('superwhammy', 1),
#  ('gig', 1),
#  ('accompaniment', 1),
#  ('equipment', 1),
#  ('individual', 1),
#  ('dubdelay', 1),
#  ('vinyl', 1),
#  ('dimarzio', 1),
#  ('filteredcapo', 1),
#  ('go', 1),
#  ('set', 1),
#  ('calf', 1),
#  ('vibrochump', 1),
#  ('spread', 1),
#  ('crazy', 1),
#  ('boost', 1),
#  ('sub-bells', 1),
#  ('circuitjam', 1),
#  ('guitarist', 1),
#  ('dubfx', 1),
#  ('fingers', 1),
#  ('duck', 1),
#  ('youtube', 1),
#  ('filterclavier', 1),
#  ('kit', 1),
#  ('pra', 1),
#  ('pitchshift', 1),
#  ('pitch-shifter', 1),
#  ('rgx312', 1),
#  ('experiment', 1),
#  ('envelope', 1),
#  ('details', 1),
#  ('amplifier', 1),
#  ('ambient', 1),
#  ('beatbox+click', 1),
#  ('amplifiers', 1),
#  ('trumpet/harmonics', 1),
#  ('ftw', 1),
#  ('game', 1),
#  ('beatings', 1),
#  ('community', 1),
#  ('e-piano', 1),
#  ('switch', 1),
#  ('pinknoise', 1),
#  ('music', 1),
#  ('replikant', 1),
#  ('epic', 1),
#  ('cc14', 1),
#  ('invada', 1),
#  ('leslie', 1),
#  ('hand', 1),
#  ('sit', 1),
#  ('combo', 1),
#  ('volca', 1),
#  ("'whirl", 1),
#  ('fluiddrums', 1),
#  ('solo', 1),
#  ('worell', 1),
#  ('round', 1),
#  ('quest', 1),
#  ('fluid', 1),
#  ('isso', 1),
#  ('activation', 1),
#  ('funk', 1),
#  ('play', 1),
#  ('/', 1),
#  ('mverb', 1),
#  ('od-leslie', 1),
#  ('dickinson', 1),
#  ('clearer', 1),
#  ('toggles', 1),
#  ('experiments', 1),
#  ('stuff', 1),
#  ('controller', 1),
#  ('dp102', 1),
#  ('ft.', 1),
#  ('gui', 1),
#  ('yamaha', 1),
#  ('trumpetbassandlead', 1),
#  ('pjotr', 1),
#  ('transformer', 1),
#  ('showboard', 1),
#  ('fuzzface', 1),
#  ('dense', 1),
#  ('midistuffdemo', 1),
#  ('vibe', 1),
#  ('jamm', 1),
#  ('ancient', 1),
#  ('set-up', 1),
#  ('courtesy', 1),
#  ('attacks', 1),
#  ('bassy', 1),
#  ('options', 1),
#  ('hum', 1),
#  ('modduo', 1),
#  ('tones', 1),
#  ('plugin', 1),
#  ('bridge', 1),
#  ('club', 1),
#  ('level', 1),
#  ('processing', 1),
#  ('share', 1),
#  ('c0d3man', 1),
#  ('mirror', 1),
#  ('ch', 1),
#  ('shimmer/reflector/reverb', 1),
#  ('d', 1),
#  ('o', 1),
#  ('softstep', 1),
#  ('sides', 1),
#  ('harmonica', 1),
#  ('arms', 1),
#  ('warm', 1),
#  ('madness', 1),
#  ('hpf', 1),
#  ('+3/-3', 1),
#  ('don', 1),
#  ('hammond', 1),
#  ('drumsounds', 1),
#  ('textures', 1),
#  ('epiphone', 1),
#  ('strings', 1),
#  ('pausenfüller', 1),
#  ('impulse', 1),
#  ('e', 1),
#  ('width', 1),
#  ('thyme', 1),
#  ('enter', 1),
#  ('zt', 1),
#  ('difference', 1),
#  ('label', 1),
#  ('auto-wah', 1),
#  ('title', 1),
#  ('harmonicos', 1),
#  ('shifters', 1),
#  ('equalizer', 1),
#  ('player', 1),
#  ('step', 1),
#  ('analog', 1),
#  ('lawson', 1),
#  ('device', 1),
#  ('jam', 1),
#  ('oldschool', 1),
#  ('levels', 1),
#  ('ceo', 1),
#  ('telecaster', 1),
#  ('clarity', 1),
#  ('problem', 1),
#  ('range', 1),
#  ('part', 1),
#  ('travel', 1),
#  ('rock/blues/country', 1)]
