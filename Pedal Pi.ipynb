# %%
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav

rate, data = wav.read('pedalpi/guitarrinha.wav')

plt.plot(data)
plt.show()
